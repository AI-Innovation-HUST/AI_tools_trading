# %%
import pandas as pd
import talib

# %%
data_full = pd.read_csv('Dataset/test.csv')
indicators = talib.get_functions()

# %%
data_full
# Out:
#                  ts        o        h        l        c        vol  \
# 0     1640969940000  47485.5  47519.9  47443.3  47476.1  12.148750
# 1     1640969880000  47536.2  47538.7  47432.0  47485.5  26.707046
# 2     1640969820000  47566.8  47566.8  47517.6  47536.2  10.776975
# 3     1640969760000  47493.3  47570.0  47466.8  47566.7  24.330524
# 4     1640969700000  47599.4  47599.6  47454.0  47493.4  24.941196
# ...             ...      ...      ...      ...      ...        ...
# 2874  1640797500000  47699.5  47700.9  47699.4  47700.9   0.087606
# 2875  1640797440000  47674.5  47706.0  47666.9  47699.5   2.181096
# 2876  1640797380000  47690.1  47690.1  47670.0  47673.2   1.902989
# 2877  1640797320000  47726.9  47726.9  47692.2  47692.2   1.061390
# 2878  1640797260000  47675.0  47735.3  47674.9  47726.8   1.963055
#
#             volCcy   volCcyQuote  confirm
# 0     5.768326e+05  5.768326e+05        1
# 1     1.267923e+06  1.267923e+06        1
# ...

# %%
indicators = talib.get_functions()
data_full['SMA'] = talib.MA(data_full['c'], timeperiod = 20)

# %%
import ta
df = ta.add_all_ta_features(data_full, "o", "h", "l", "c", "vol", fillna=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                  ts        o        h        l        c       vol  \
# 19    1640968800000  47899.1  47918.6  47894.3  47918.5  1.783747
# 20    1640968740000  47900.0  47900.0  47881.5  47899.2  1.737565
# 21    1640968680000  47897.2  47899.5  47880.0  47897.2  3.636616
# 22    1640968620000  47914.5  47918.0  47900.0  47900.0  1.069737
# 23    1640968560000  47927.1  47927.2  47900.0  47911.6  5.009514
# ...             ...      ...      ...      ...      ...       ...
# 2874  1640797500000  47699.5  47700.9  47699.4  47700.9  0.087606
# 2875  1640797440000  47674.5  47706.0  47666.9  47699.5  2.181096
# 2876  1640797380000  47690.1  47690.1  47670.0  47673.2  1.902989
# 2877  1640797320000  47726.9  47726.9  47692.2  47692.2  1.061390
# 2878  1640797260000  47675.0  47735.3  47674.9  47726.8  1.963055
#
#              volCcy    volCcyQuote  confirm        SMA  ...  momentum_ppo  \
# 19     85441.549639   85441.549639        1  47726.030  ...      0.231890
# ...

# %%
df.to_csv('Dataset/test1.csv', index=False)

# %%
# h = h
# l = low
# o = o
# c = c
# v = vol

indicators = ta.get_functions()

indicators.remove('AD')
indicators.remove('ADOSC')
indicators.remove('MFI')
indicators.remove('OBV')

hlcv_indicators = ['AD','ADOSC','MFI']
cl_indicators = ['OBV']


data_full_with_indi = []




# data_full = data_full.copy()
for indicator in indicators:
    print(indicator)        # indi need 1 value
    try: 
        name = ta.Function(indicator)(data_full['c'])
        if len(name)>100:
            data_full[indicator] = name
        else:
            for i in range(len(name)):
                data_full[indicator] = name[i]
    except Exception as e:
        print(e)
        # print(e)

    # indi need 2 value
    try: 
        name = ta.Function(indicator)(data_full['h'],data_full['l'])
        if len(name)>100:
            data_full[indicator] = name
        else:
            for i in range(len(name)):
                data_full[indicator] = name[i]
    except Exception as e:
        print(e) 

    # indi need 3 value       
    try:
        name = ta.Function(indicator)(data_full['h'],data_full['l'],data_full['c'])
        if len(name)>100:
            data_full[indicator] = name
        else:
            for i in range(len(name)):
                data_full[indicator] = name[i]
    except Exception as e:
        print(e)

    # indi need 4 value
    try: 
        name = ta.Function(indicator)(data_full['o'],data_full['h'],data_full['l'],data_full['c'])
        if len(name)>100:
            data_full[indicator] = name
        else:
            for i in range(len(name)):
                data_full[indicator] = name[i]
    except Exception as e:
        print(e)

# others indi that need specific value
for hlcv_indicator in hlcv_indicators:
    try: 
        name = ta.Function(hlcv_indicator)(data_full['o'],data_full['h'],data_full['c'],data_full['vol'])
        if len(name)>100:
            data_full[indicator] = name
        else:
            for i in range(len(name)):
                data_full[indicator] = name[i]
    except Exception as e:
        print(e) 
for cl_indicator in cl_indicators:
    try: 
        name = ta.Function(cl_indicator)(data_full['c'],data_full['vol'])
        if len(name)>100:
            data_full[indicator] = name
        else:
            for i in range(len(name)):
                data_full[indicator] = name[i]
    except Exception as e:
        print(e) 
data_full_with_indi.append(data_full)


data_full_full = []
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 7
#       1 # h = h
#       2 # l = low
#       3 # o = o
#       4 # c = c
#       5 # v = vol
# ----> 7 indicators = ta.get_functions()
#       9 indicators.remove('AD')
#      10 indicators.remove('ADOSC')
#
# AttributeError: module 'ta' has no attribute 'get_functions'

# %%
data_with_indi
# Out:
# ['ts', 'o', 'h', 'l', 'c', 'vol', 'volCcy', 'volCcyQuote', 'confirm']
